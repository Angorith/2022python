# %% [markdown]
# <a href="https://colab.research.google.com/github/Angorith/acorn_python/blob/main/0610_24%EC%9D%BC%EC%B0%A8_AI(%EB%94%A5%EB%9F%AC%EB%8B%9D)%2Cnumpy%5Bmask%2Czeros%2Cones%2Cempty%2Czeros_like%2Cones_like%2Cempty_like%2Clinspace%2Cmin%2Cmax%2Cargmax%2Cargmin%2Cexp%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 경사하강법
# 기울기가 0인 지점을 찾아가서 결국에는 오차가 최소인 것을 찾아가는 방법
#
# 그걸 사용해서 딥러닝을 사용하게 된다.
# 가중치값을 얻어야한다. (a1가중치 a0편향)
# 그러나 우리는 그러한 수학 과정 없이 간다.
# 수학에서 증명하는 이유는 명제를 받아드릴 수 있기 때문이다.

# %% [markdown]
# ![캡처.PNG](data:image/png;base64,...)

# %%
arr = np.array([1,2,3,4,5,4,4])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5, 4, 4])

# %%
x = np.where(arr==4)

# %% [markdown]
# , 는 tuple을 의미함

# %%
x
# Out:
# (array([3, 5, 6]),)

# %%
type(x)
# Out:
# tuple

# %%
arr = np.arange(6).reshape((2,3))

# %%
arr
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
np.where(arr<3) #위치를 나타내는 index값 출력   array([0번째 raw]), array([번째 칼럼])
# Out:
# (array([0, 0, 0]), array([0, 1, 2]))

# %%
np.where(arr<3, 100,-100)   #arr(값이) 3보다 작으면 100, 크면 -100
# Out:
# array([[ 100,  100,  100],
#        [-100, -100, -100]])

# %%
np.where(arr<3, 100,arr)
# Out:
# array([[100, 100, 100],
#        [  3,   4,   5]])

# %%
arr = np.array([3,2,0,1])

# %%
np.sort(arr)
# Out:
# array([0, 1, 2, 3])

# %%
arr
# Out:
# array([3, 2, 0, 1])

# %%
arr.sort()    #arr값 자체를 바꾸고 싶으면

# %%
arr
# Out:
# array([0, 1, 2, 3])

# %%
arr>2   #값은 bool 값으로 나타남(T,F)
# Out:
# array([False, False, False,  True])

# %%
arr = np.array([41,42,43,44])

# %%
arr
# Out:
# array([41, 42, 43, 44])

# %%
x=[True,False,True,False]   #외우기

# %%
arr[x]
# Out:
# array([41, 43])

# %%
mx = np.ma.array([1,2,3,4,5], mask = [True,False,False,False,False])   #mask : bool값 적용해서 True는 걸러서 출력

# %%
print(mx)   #False값만 출력
# Out:
# [-- 2 3 4 5]

# %%
mx.data
# Out:
# array([1, 2, 3, 4, 5])

# %%
mx.mask
# Out:
# array([ True, False, False, False, False])

# %%
d = np.array([10,20,30,40,50])

# %%
d[mx.mask]  #true값 출력
# Out:
# array([10])

# %% [markdown]
# 어렵다

# %%
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((2,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.empty((2,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
arr = np.array([[1.,2.],[2.,3.]])

# %%
arr
# Out:
# array([[1., 2.],
#        [2., 3.]])

# %%
np.zeros_like(arr)  #형태는 똑같으나 값이 0
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %%
np.ones_like(arr)
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
brr = np.arange(10).reshape((2,5))

# %%
np.empty_like(brr)
# Out:
# array([[           56312016,                  36,                   0,
#                           0,                   0],
#        [3544395811724015973, 3833739083393348653, 3256724177262830689,
#         7076106518301717304,           926366007]])

# %%
np.linspace(1,4,num=10) #1~3까지 10개간격으로 쪼개기
# Out:
# array([1.        , 1.33333333, 1.66666667, 2.        , 2.33333333,
#        2.66666667, 3.        , 3.33333333, 3.66666667, 4.        ])

# %%
a = np.array([[1,2],[3,4]])

# %%
b = np.array([[5,6],[7,8]])

# %%
a,b
# Out:
# (array([[1, 2],
#         [3, 4]]), array([[5, 6],
#         [7, 8]]))

# %%
np.dot(a,b)
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
a+b
# Out:
# array([[ 6,  8],
#        [10, 12]])

# %%
a-b
# Out:
# array([[-4, -4],
#        [-4, -4]])

# %%
a+100
# Out:
# array([[101, 102],
#        [103, 104]])

# %%
a*b
# Out:
# array([[ 5, 12],
#        [21, 32]])

# %% [markdown]
# # 2

# %%
a/b
# Out:
# array([[0.2       , 0.33333333],
#        [0.42857143, 0.5       ]])

# %%
c = np.array([10,30])

# %%
a.shape, b.shape, c.shape
# Out:
# ((2, 2), (2, 2), (2,))

# %%
a+c
# Out:
# array([[11, 32],
#        [13, 34]])

# %%
a+b
# Out:
# array([[ 6,  8],
#        [10, 12]])

# %%
c
# Out:
# array([10, 30])

# %%
a
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
a*c
# Out:
# array([[ 10,  60],
#        [ 30, 120]])

# %%
a+c
# Out:
# array([[11, 32],
#        [13, 34]])

# %%
a3 = np.array([1,10,100])
b3 = np.array([1])

# %%
a3-b3
# Out:
# array([ 0,  9, 99])

# %%
a4 = np.arange(3)

# %%
a4
# Out:
# array([0, 1, 2])

# %%
a4+5
# Out:
# array([5, 6, 7])

# %%
a3
# Out:
# array([  1,  10, 100])

# %%
b3
# Out:
# array([1])

# %%
a3+b3
# Out:
# array([  2,  11, 101])

# %%
a3 = np.array([[1,10,100], [1000,1000,1000]])
b3 = np.array([1,2,3])

# %%
a3-b3
# Out:
# array([[  0,   8,  97],
#        [999, 998, 997]])

# %%
a = np.arange(6).reshape((2,3))

# %%
a
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
a.T
# Out:
# array([[0, 3],
#        [1, 4],
#        [2, 5]])

# %%
a2 = np.arange(6).reshape((3,2))

# %%
a2
# Out:
# array([[0, 1],
#        [2, 3],
#        [4, 5]])

# %%
np.sum(a2, axis=0)
# Out:
# array([6, 9])

# %%
np.sum(a2, axis=1)
# Out:
# array([1, 5, 9])

# %%
np.mean(a2, axis=0)
# Out:
# array([2., 3.])

# %%
np.mean(a2, axis=1)
# Out:
# array([0.5, 2.5, 4.5])

# %%
np.mean(a2)
# Out:
# 2.5

# %%
np.max(a2)
# Out:
# 5

# %%
np.max(a2, axis=0)
# Out:
# array([4, 5])

# %%
np.max(a2, axis=1)
# Out:
# array([1, 3, 5])

# %%
a2
# Out:
# array([[0, 1],
#        [2, 3],
#        [4, 5]])

# %%
a2-np.max(a2)
# Out:
# array([[-5, -4],
#        [-3, -2],
#        [-1,  0]])

# %%
a2-np.max(a2, axis=0)
# Out:
# array([[-4, -4],
#        [-2, -2],
#        [ 0,  0]])

# %%
a2-np.max(a2, axis=1)   #에러가 난다
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-d9bd5bb710dc> in <module>()
# ----> 1 a2-np.max(a2, axis=1)
#
# ValueError: operands could not be broadcast together with shapes (3,2) (3,)

# %%
a2.shape
# Out:
# (3, 2)

# %%
np.max(a2, axis=0).shape, np.max(a2, axis=1).shape
# Out:
# ((2,), (3,))

# %%
np.min(a2)
# Out:
# 0

# %%
np.min(a2, axis=0)
# Out:
# array([0, 1])

# %%
np.min(a2, axis=1)
# Out:
# array([0, 2, 4])

# %%
np.argmax(a2)
# Out:
# 5

# %%
a2 = np.array([[10,20,30],[40,50,60]])

# %%
a2
# Out:
# array([[10, 20, 30],
#        [40, 50, 60]])

# %%
np.argmax(a2)
# Out:
# 5

# %%
np.max(a2, axis=0)
# Out:
# array([40, 50, 60])

# %%
np.min(a2, axis=0)
# Out:
# array([10, 20, 30])

# %%
np.max(a2, axis=1)
# Out:
# array([30, 60])

# %%
np.min(a2, axis=1)
# Out:
# array([10, 40])

# %%
np.argmax(a2, axis=0)   #최대값에 대한 index번호를 반환 #row 기준
# Out:
# array([1, 1, 1])

# %%
np.argmin(a2, axis=0)   #최소값에 대한 index번호를 반환 #row 기준
# Out:
# array([0, 0, 0])

# %%
np.argmax(a2, axis=1)   #최대값에 대한 index번호를 반환 #column 기준
# Out:
# array([2, 2])

# %%
np.argmin(a2, axis=1)    #최소값에 대한 index번호를 반환 #column 기준
# Out:
# array([0, 0])

# %%
a
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
b
# Out:
# array([[5, 6],
#        [7, 8]])

# %%
np.exp(a)   #expernation 지수함수
# Out:
# array([[  1.        ,   2.71828183,   7.3890561 ],
#        [ 20.08553692,  54.59815003, 148.4131591 ]])

# %%
np.sum(np.exp(a),axis=0)
# Out:
# array([ 21.08553692,  57.31643186, 155.8022152 ])

# %%
2*2
# Out:
# 4

# %%
2*2*2
# Out:
# 8

# %%
2**3    #2의 3제곱
# Out:
# 8

# %%
np.e
# Out:
# 2.718281828459045

# %%
x = np.array([1,2,3,4])

# %%
np.sin(x)
# Out:
# array([ 0.84147098,  0.90929743,  0.14112001, -0.7568025 ])

# %%
plt.plot(x, np.sin(x))

# %%
x = np.arange(0,10,0.1)

# %%
np.sin(x)
# Out:
# array([ 0.        ,  0.09983342,  0.19866933,  0.29552021,  0.38941834,
#         0.47942554,  0.56464247,  0.64421769,  0.71735609,  0.78332691,
#         0.84147098,  0.89120736,  0.93203909,  0.96355819,  0.98544973,
#         0.99749499,  0.9995736 ,  0.99166481,  0.97384763,  0.94630009,
#         0.90929743,  0.86320937,  0.8084964 ,  0.74570521,  0.67546318,
#         0.59847214,  0.51550137,  0.42737988,  0.33498815,  0.23924933,
#         0.14112001,  0.04158066, -0.05837414, -0.15774569, -0.2555411 ,
#        -0.35078323, -0.44252044, -0.52983614, -0.61185789, -0.68776616,
#        -0.7568025 , -0.81827711, -0.87157577, -0.91616594, -0.95160207,
#        -0.97753012, -0.993691  , -0.99992326, -0.99616461, -0.98245261,
#        -0.95892427, -0.92581468, -0.88345466, -0.83226744, -0.77276449,
#        -0.70554033, -0.63126664, -0.55068554, -0.46460218, -0.37387666,
#        -0.2794155 , -0.1821625 , -0.0830894 ,  0.0168139 ,  0.1165492 ,
# ...

# %%
plt.plot(x, np.sin(x))

# %%
np.exp(x)
# Out:
# array([1.00000000e+00, 1.10517092e+00, 1.22140276e+00, 1.34985881e+00,
#        1.49182470e+00, 1.64872127e+00, 1.82211880e+00, 2.01375271e+00,
#        2.22554093e+00, 2.45960311e+00, 2.71828183e+00, 3.00416602e+00,
#        3.32011692e+00, 3.66929667e+00, 4.05519997e+00, 4.48168907e+00,
#        4.95303242e+00, 5.47394739e+00, 6.04964746e+00, 6.68589444e+00,
#        7.38905610e+00, 8.16616991e+00, 9.02501350e+00, 9.97418245e+00,
#        1.10231764e+01, 1.21824940e+01, 1.34637380e+01, 1.48797317e+01,
#        1.64446468e+01, 1.81741454e+01, 2.00855369e+01, 2.21979513e+01,
#        2.45325302e+01, 2.71126389e+01, 2.99641000e+01, 3.31154520e+01,
#        3.65982344e+01, 4.04473044e+01, 4.47011845e+01, 4.94024491e+01,
#        5.45981500e+01, 6.03402876e+01, 6.66863310e+01, 7.36997937e+01,
#        8.14508687e+01, 9.00171313e+01, 9.94843156e+01, 1.09947172e+02,
#        1.21510418e+02, 1.34289780e+02, 1.48413159e+02, 1.64021907e+02,
# ...

# %%
plt.plot(x, np.exp(x))

# %%
np.exp(0)
# Out:
# 1.0

# %%
np.exp(1)
# Out:
# 2.718281828459045

# %%
np.exp(1000)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: overflow encountered in exp
#   """Entry point for launching an IPython kernel.
# inf

# %% [markdown]
# # 3

# %% [markdown]
# 밑바닥부터 시작하는 딥러닝 1, 한빛미디어
#
# 퍼셉트론(인공뉴런): 다수의 신호를 입력받아 하나의 신호를 출력
#
# 신호 : 흐른다(1), 흐르지 않는다(0) 두가지 값을 가짐
#
# 입력신호 : x1, x2
#
# 출력신호 : y1
#
# 가중치  : w1, w2(w는 weight의 머리글자)
#
# 퍼셉트론에서는 가중치가 클수록 강한 신호를 흘림.
#
# 전류에서 말하는 저항. 저항이 낮을 수록 큰 전류가 흐름

# %% [markdown]
# $$
# y =x1* w1 + x2 *w2
# $$

# %% [markdown]
# ex)
# $$
# y = w_1 x_1 + w_2x_2 <=100
# $$

# %% [markdown]
# $$
# y = 0(w1x1 + w2x2 <=theta(b1))
# $$
# $$
# y = 1(w1x1 + w2x2 <=theta(b1))
# $$
#
# theta를 b1으로 표시
#
# 0이면 안넘기고 1이면 넘긴다.
# (그 뒤 식에서 또 사용한다.)
#
# 동그라미 : 노드
#
# 흐르는 화살표 : 엣지
#
# b1 = 쎄터?

# %% [markdown]
# ![캡처.PNG](data:image/png;base64,...)

# %% [markdown]
# $$
# y = 0(b1 + x1w1 + x2w2 <=theta(0))
# $$
# $$
# y = 1(b1 +x1w1 + x2w2 <=theta(0))
# $$

# %% [markdown]
# ```
# # 코드로 형식 지정됨
# a +b =3
#
# a = 3-b
#
# c = -b
#
# a = 3+c
#
# y 0(a<=0)
#   1(a> 10)
#
# y = h(a)
#
# def h(a):
#     if a<=:
#         result = 0
#     else:
#         result = 1
#     return result
#
# y = h(a)
# ```

# %% [markdown]
# $$
# y = h(b_1 + x_1w_1 + x_2w_2)
# $$
# $$
# a = b_1+x_1w_1+x_2W_2
# $$

# %%
a= 10

# %%
def h(a): 
    if a <=0 :
        result =0
    else:
        result = 1
    return result

# %%
h(10)
# Out:
# 1

# %%
y = h(a)

# %% [markdown]
# # 4

# %%
def AND(x1, x2):
    w1, w2 , theta = 0.5, 0.5, 0.7
    tmp = x1*w1 + x2*w2
    if tmp <= theta:
        return 0
    elif tmp>theta:
        return 1

# %%
AND(0,0)
# Out:
# 0

# %%
print(AND(0,0))
print(AND(1,0))
print(AND(0,1))
print(AND(1,1))
# Out:
# 0
# 0
# 0
# 1

# %%
def AND(x1, x2):
    w1, w2 , theta = 0.5, 0.5, 0.7
    b1 = -theta
    tmp = x1*w1 + x2*w2 +b1
    print(tmp)
    if tmp <=0:
        return 0
    elif tmp>0:
        return 1

# %%
print(AND(0,0))
print(AND(1,0))
print(AND(0,1))
print(AND(1,1))
# Out:
# -0.7
# 0
# -0.19999999999999996
# 0
# -0.19999999999999996
# 0
# 0.30000000000000004
# 1

# %%
w1 *x1 = 0.5 * 0 , w2*x2 = 0.5*1 , b1 = -0.7

0+0.5-0.7= -0.2

# %%
x = np.array([0,1])
w = np.array([0.5,0.5])
b = -0.7

# %%
np.sum(w*x)
# Out:
# 0.5

# %%
np.dot(x,w)
# Out:
# 0.5

# %%
z1 = np.dot(x,w)+b

# %%
if z1 <=0:
    y = 0
else :
    y =1

# %%
y
# Out:
# 0

# %%
def AND(x1, x2):
    x = np.array([x1, x2])
    w = np.array([0.5,0.5])
    b = -0.7
    z1 = np.dot(x,w)+b
    print(x, w, b, z1)
    if z1 <=0:
        return 0
    else:
        return 1

# %%
print(AND(0,0))
print(AND(1,0))
print(AND(0,1))
print(AND(1,1))
# Out:
# [0 0] [0.5 0.5] -0.7 -0.7
# 0
# [1 0] [0.5 0.5] -0.7 -0.19999999999999996
# 0
# [0 1] [0.5 0.5] -0.7 -0.19999999999999996
# 0
# [1 1] [0.5 0.5] -0.7 0.30000000000000004
# 1

# %%
def OR(x1, x2 ):
    x = np.array([x1, x2])
    w = np.array([0.5,0.5])
    b = -0.2
    z1 = np.dot(x,w)+b
    print(x, w, b, z1)
    if z1 <=0:
        return 0
    else:
        return 1

# %%
print(OR(0,0))
print(OR(1,0))
print(OR(0,1))
print(OR(1,1))
# Out:
# [0 0] [0.5 0.5] -0.2 -0.2
# 0
# [1 0] [0.5 0.5] -0.2 0.3
# 1
# [0 1] [0.5 0.5] -0.2 0.3
# 1
# [1 1] [0.5 0.5] -0.2 0.8
# 1

# %%
def NAND(x1, x2 ):  #not AND
    x = np.array([x1, x2])
    w = np.array([-0.5,-0.5])
    b = 0.7
    z1 = np.dot(x,w)+b
    print(x, w, b, z1)
    if z1 <=0:
        return 0
    else:
        return 1

# %%
print(NAND(0,0))
print(NAND(1,0))
print(NAND(0,1))
print(NAND(1,1))
# Out:
# [0 0] [-0.5 -0.5] 0.7 0.7
# 1
# [1 0] [-0.5 -0.5] 0.7 0.19999999999999996
# 1
# [0 1] [-0.5 -0.5] 0.7 0.19999999999999996
# 1
# [1 1] [-0.5 -0.5] 0.7 -0.30000000000000004
# 0

# %% [markdown]
# AND + OR + NAND = XOR

# %% [markdown]
# 가중치 (w1, w2) 는 입력 신호가 결과에 주는 영향력(중요도)를 조절하는 매개변수
#
# 편향(b)는 뉴런이 얼마나 쉽게 활성화(결과로 1을 출력) 하느냐를 조정하는 매개변수
#
# 예시) b가 -0.1이면 가중치를 곱한 합이 0.1을 초과할 때, 뉴런이 활성화됨

# %%
x1 = np.arange(-1, 3, 0.1)
x2 = -x1 + 0.5

plt.axvline(x=0, color = 'b')
plt.axhline(y=0, color = 'b')

plt.xlabel('X1')
plt.ylabel('X2')

plt.fill_between(x1, x2, -3, color='grey', alpha=0.5)

plt.scatter([1,01])
